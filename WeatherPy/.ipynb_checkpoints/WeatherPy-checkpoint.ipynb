# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
country = []
lat = []
lon = []
temp = []
humid = []
cloud = []
wind = []
found_cities = []
date = []


# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        found_cities.append(response['name'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except KeyError:
        print(city + ' not found')
    else:
        print(response['name'])
        
        
## HOW TO NUMBER CITIES output?
## HOW TO OUTPUT JPG?
# Out:
# Albany
# Greeneville
# Rikitea
# Punta Arenas
# Puerto Escondido
# Santa Maria
# Chepareria
# Bengkulu
# Talnakh
# Toamasina
# Bluff
# Qaanaaq
# Borba
# Arraial do Cabo
# Dikson
# Jamestown
# Chervonohryhorivka
# Tiksi
# Atuona
# Sisimiut
# Rome
# Saint Paul Harbor
# Ponta do Sol
# Kapit
# Thompson
# Eyl
# Ushuaia
# Umm Kaddadah
# Busselton
# Kaitangata
# Chui
# Kahului
# São João da Barra
# Saint George
# Bambous Virieux
# Vardø
# aflu not found
# Tutóia
# Avarua
# grand river south east not found
# Acapulco de Juárez
# Hanzhong
# Kapaa
# Bredasdorp
# Butaritari
# illoqqortoormiut not found
# Constitución
# Port Lincoln
# Cidreira
# Terrace
# Mar del Plata
# taolanaro not found
# Nikolskoye
# ijaki not found
# San Patricio
# nizhneyansk not found
# Husavik
# Barrow
# New Norfolk
# Hilo
# Airai
# Mataura
# Lorengau
# Provideniya
# George Town
# Karratha
# Guérande
# Tasiilaq
# San Lorenzo
# Bairiki Village
# Ati
# Chapais
# Tymovskoye
# warqla not found
# Devils Lake
# Tuatapere
# Beloha
# Nizhnyaya Salda
# Cape Town
# Torbay
# Mount Gambier
# Quelimane
# Jackson
# belushya guba not found
# Hobart
# Zyryanovsk
# Mayskiy
# Hermanus
# Mahébourg
# Niquero
# Lebu
# Nizhnyaya Tavda
# Khasan
# Aitape
# Pevek
# Upernavik
# Flin Flon
# Aklavik
# Vaini
# Yangi Marg`ilon
# Arlit
# kuche not found
# Nome
# Whitecourt
# Laguna
# Pori
# Nizhniy Ingash
# Mossamedes
# Valparaíso
# Puerto Ayora
# barentsburg not found
# Hithadhoo
# Riyadh
# Perivoli
# East London
# Khatanga
# Clyde River
# Touros
# Camrose
# Gobabis
# tsihombe not found
# Wanning
# Leningradskiy
# dmitriyev-lgovskiy not found
# Onega
# Klaksvík
# Port Alfred
# Bundaberg
# Anadyr
# Humaitá
# Ribeira Grande
# Richards Bay
# Bindi
# Castro
# Tocopilla
# Uva
# Gusau
# Taoudenni
# Yellowknife
# Velikiy Ustyug
# Lagoa
# Nueve de Julio
# Mastic Beach
# Stornoway
# Korla
# turtkul not found
# Watsa
# Hasaki
# Cherskiy
# Muros
# riaba not found
# Muli
# Hazleton
# Bubaque
# Tuktoyaktuk
# Del Rio
# Saint-Leu
# Corralillo
# Turukhansk
# Hvolsvollur
# Fes
# Dubki
# saryshagan not found
# Doha
# Cap-aux-Meules
# Sechura
# Nicolás Bravo
# Esim
# La Santisima Trinidad
# Churhat
# Kruisfontein
# Chagoda
# Bhag
# kollumerland not found
# Freeport
# Itanhandu
# Aswān
# Balakhta
# Chake Chake
# Fare
# Evensk
# Marshall
# Umm Hājar
# Lamar
# Lunenburg
# Praia
# Lālmohan
# Lata
# Dalbandin
# Forestville
# Grindavik
# Aripuanã
# hihifo not found
# Três Lagoas
# louisbourg not found
# Hammerfest
# Jyvaskyla
# Road Town
# Grand-Santi
# dzhusaly not found
# uwayl not found
# Iisalmi
# Atasū
# haibowan not found
# Lerwick
# Bayshore Gardens
# Brae
# Talaya
# Asău
# Karema
# Seymchan
# Berlevåg
# Port Keats
# artyk not found
# Mitú
# Margate
# Belyy Yar
# Honiara
# Buraidah
# Santiago
# vaitupu not found
# Betioky
# Jiblah
# Rocha
# Sobolevo
# Ukiah
# At-Bashi
# Artigas

# %%
weather_dic = {
    'city' : found_cities,
    'country': country,
    'latitude' : lat,
    'longitude' : lon,
    'temperature' : temp,
    'humidity' : humid,
    'cloudy' : cloud,
    'wind speed' : wind,
    'date' : date
     }

weather_data2 = pd.DataFrame(weather_dic)
weather_data = weather_data2.loc[weather_data2['humidity']< 101]

# %%
weather_data
# Out:
#                  city country  latitude  longitude  temperature  humidity  \
# 0              Albany      US     42.60     -73.97        72.55        90
# 1         Greeneville      US     36.16     -82.83        81.64        61
# 2             Rikitea      PF    -23.12    -134.97        67.23        59
# 3        Punta Arenas      CL    -53.15     -70.92        28.20        92
# 4    Puerto Escondido      MX     15.85     -97.07        82.40        74
# ..                ...     ...       ...        ...          ...       ...
# 548             Rocha      UY    -34.48     -54.33        66.18        94
# 549          Sobolevo      RU     54.43      31.90        49.12        95
# 550             Ukiah      US     39.15    -123.21        85.87        31
# 551          At-Bashi      KG     41.17      75.81        53.31        58
# 552           Artigas      UY    -30.40     -56.47        67.28        80
#
#      cloudy  wind speed        date
# 0        47        2.51  1595464521
# 1         1        4.70  1595464722
# 2       100       13.65  1595464723
# 3        77        5.82  1595464682
# 4        90        2.82  1595464723
# ..      ...         ...         ...
# 548     100        8.43  1595464859
# 549       2        9.98  1595464859
# 550       1        4.70  1595464853
# 551       0        0.83  1595464859
# 552     100        6.02  1595464860
#
# [553 rows x 9 columns]

# %%
#latitude vs temperature
plt.scatter(weather_data['latitude'],weather_data['temperature'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Latitude & Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
#latitude vs humidty
plt.scatter(weather_data['latitude'], weather_data['humidity'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Latitude & Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidty")
# Out:
# Text(0, 0.5, 'Humidty')

# %%
#latitude vs cloudiness
plt.scatter(weather_data['latitude'], weather_data['cloudy'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Latitude & Cloud Cover")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %%
#latitude vs wind speed
plt.scatter(weather_data['latitude'],weather_data ['wind speed'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Latitude & Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# Text(0, 0.5, 'Wind Speed')

# %%
northern = weather_data.loc[weather_data['latitude'] > 0]

# %%
southern = weather_data.loc[weather_data['latitude'] <= 0]

# %%
# southern latitude vs temperature
plt.scatter(southern['latitude'], southern['temperature'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Southern Hemisphere Latitude & Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# northern latitude vs temperature
plt.scatter(northern['latitude'],northern['temperature'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Northern Hemisphere Latitude & Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# northern latitude vs humidity
plt.scatter(northern['latitude'],northern['humidity'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Northern Hemisphere Latitude & Humidty")
plt.xlabel("Latitude")
plt.ylabel("Humidty")
# Out:
# Text(0, 0.5, 'Humidty')

# %%
# southern latitude vs humidity
plt.scatter(southern['latitude'],southern['humidity'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Southern Hemisphere Latitude & Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# Text(0, 0.5, 'Humidity')

# %%
# southern latitude vs cloudiness
plt.scatter(southern['latitude'],southern['cloudy'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Southern Hemisphere Latitude & Cloud Cover")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %%
# northern latitude vs cloudiness
plt.scatter(northern['latitude'],northern['cloudy'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Northern Hemisphere Latitude & Cloud Cover")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %%
# northern latitude vs wind
plt.scatter(northern['latitude'],northern['wind speed'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)

plt.title("Northern Hemisphere Latitude & Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# Text(0, 0.5, 'Wind Speed')

# %%
# southern latitude vs wind
plt.scatter(southern['latitude'],southern['wind speed'], marker="o", facecolors="violet", edgecolors="black",
            alpha=0.75)
plt.title("Southern Hemisphere Latitude & Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# Text(0, 0.5, 'Wind Speed')

# %%
#linregress
#(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['latitude'],southern['wind speed'])

# %%
weather_data.to_csv(r'../output_data/cities.csv')
