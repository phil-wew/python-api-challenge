# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from config import g_key

pd.read_csv(r'../output_data/cities.csv')
# Out:
#      Unnamed: 0               city  latitude  temperature  humidity  cloudy  \
# 0             0  Zheleznodorozhnyy     55.75        59.59        93       0
# 1             1           Souillac    -20.52        64.40        77      75
# 2             2            Rikitea    -23.12        66.29        62       0
# 3             3          Upernavik     72.79        49.69        64     100
# 4             4              Kapaa     22.08        81.03        65      20
# ..          ...                ...       ...          ...       ...     ...
# 549         549       Río Gallegos    -51.62        24.80        92       0
# 550         550          Flin Flon     54.77        70.50        60      73
# 551         551          Shelburne     44.08        68.32        77      75
# 552         552         Seybaplaya     19.65        78.80        88      90
# 553         553             Matadi     -5.82        68.25        86      10
#
#      wind speed
# 0          6.71
# 1         12.75
# ...
